# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

cars=pd.read_csv(r'C:\Users\Jalal\Desktop\Programing\wkdir\git7\INTRO-TO-DATA-ANALYSIS\DATA\cars_multivariate.csv',na_values=['?'])
cars.head()
cars['model']=cars.model.astype('object')
cars['origin']=cars.origin.astype('object')
cars.horsepower.astype('float')
cars=cars[cars.horsepower.notna()]
numeric_vars = ['mpg','displacement','horsepower','weight','acceleration']
categorical_vars = ['model', 'origin', 'cylinders','car_name']

# %%
sns.set(rc={'figure.figsize':(16,4)})
sns.set_style('ticks')
sns.set_context('poster')
sns.boxplot(cars['weight'],color='g')
sns.despine()

# %%
cars.columns
# cars.model.dtype
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
mean=cars.mpg.mean()
sns.distplot(cars.mpg,kde=True, color='g')
plt.axvline(mean, color='r')

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
sns.barplot('origin', 'mpg', data=cars, ci=False, hue='cylinders', palette=['r','b','g','c','y'])

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(14,10)})
sns.boxplot('origin', 'mpg', data=cars, orient='v', hue='model', color='r')

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
sns.boxplot('origin', 'horsepower',data=cars, showfliers=True, fliersize=10)
# sns.swarmplot('origin', 'horsepower', data=cars, color='y')

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
sns.scatterplot( x='horsepower',y='mpg', data=cars, hue='weight',style='origin',size='horsepower',sizes=(20,200))

# %%
cars.corr()[['mpg','cylinders']]
# Out:
#                    mpg  cylinders
# mpg           1.000000  -0.777618
# cylinders    -0.777618   1.000000
# displacement -0.805127   0.950823
# horsepower   -0.778427   0.842983
# weight       -0.832244   0.897527
# acceleration  0.423329  -0.504683

# %%
sns.lmplot('horsepower','mpg', data=cars, height=10, ci=False)

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
sns.lmplot('horsepower', 'mpg', data=cars, col='origin', ci=False, line_kws={'color':'r'}, scatter_kws={'color':'b'})

# %%
sns.lmplot('horsepower', 'mpg', data=cars, col='model', col_wrap=3, line_kws={'color':'r'}, scatter_kws={'color':'c'}, height=7)

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
df1=cars[['mpg', 'cylinders','weight']].corr()

# %%
sns.heatmap(df1,annot=True)

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
sns.pairplot(cars[['mpg', 'cylinders', 'horsepower']], plot_kws={'color': 'g'})
